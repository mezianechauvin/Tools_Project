# %%
import pandas as pd
import numpy as np

# %%
# CLIENT_ID : lAFFi3W2fS4DEF5N0746Pg
# API_KEY : -lBWAWUBZqrndjWzjK9RrS3OSpCA_Haz_hjDutky0OjQcLXiLO7AAl4K_JlelcZSRNmysHWMfmHFLpf2QsPtWY1uCRIgSMJbdsqV6oTv8z00qR_lpJTkzzRa5zraW3Y

# %%
with open('./YelpAPIKeys-Copy1.txt','r') as f:
    count = 0
    for line in f:
        if count == 0:
            CLIENT_ID = line.strip()
        if count == 1:
            API_KEY = line.strip()
        count+=1

# %%
print(CLIENT_ID,API_KEY)
# Out:
# lAFFi3W2fS4DEF5N0746Pg -lBWAWUBZqrndjWzjK9RrS3OSpCA_Haz_hjDutky0OjQcLXiLO7AAl4K_JlelcZSRNmysHWMfmHFLpf2QsPtWY1uCRIgSMJbdsqV6oTv8z00qR_lpJTkzzRa5zraW3Yx

# %%
# API constants, you shouldn't have to change these.
API_HOST = 'https://api.yelp.com' #The API url header
SEARCH_PATH = '/v3/businesses/search' #The path for an API request to find businesses
BUSINESS_PATH = '/v3/businesses/'  # The path to get data for a single business

# %%
def get_restaurants(api_key,location,number=50):
    import requests
    
    #First we get the access token
    #Set up the search data dictionary
    search_data = {
    'term': "restaurant",
    'location': location.replace(' ', '+'),
    'limit': number
    }
    url = API_HOST + SEARCH_PATH
    headers = {
        'Authorization': 'Bearer %s' % api_key,
    }
    response = requests.request('GET', url, headers=headers, params=search_data).json()
    businesses = response.get('businesses')
    return businesses

# %%
restaurants_data = get_restaurants(API_KEY,"New York, NY")

# %%
def data_output(restaurants_data):
    df = pd.DataFrame(columns = ['name','is_closed','latitude','longitude','price','rating','categories','phone'])
    for i in range(len(restaurants_data)):
        name = restaurants_data[i]['name']
        is_closed = restaurants_data[i]['is_closed']
        latitude = restaurants_data[i]['coordinates']['latitude']
        longitude = restaurants_data[i]['coordinates']['longitude']
        try:
            price = restaurants_data[i]['price']
        except:
            price = None
        rating = restaurants_data[i]['rating']
        categories = []
        for categorie in restaurants_data[i]['categories']:
            categories.append(categorie['title'])
        phone = restaurants_data[i]['phone']
        
        df.loc[i] = [name,is_closed,latitude,longitude,price,rating,categories,phone]
    return(df)

# %%
data_output(restaurants_data)
# Out:
#                               name is_closed   latitude  longitude price  \
# 0                           Amélie     False  40.732700 -73.997660    $$
# 1                         LoveMama     False  40.730386 -73.986061    $$
# 2                              886     False  40.728770 -73.988730    $$
# 3                     Uglyduckling     False  40.686023 -73.991302    $$
# 4                 Burger & Lobster     False  40.740070 -73.993440    $$
# 5                  Eataly Downtown     False  40.709716 -74.011714    $$
# 6                  Jacob's Pickles     False  40.786650 -73.975528    $$
# 7                          Upstate     False  40.726314 -73.986490    $$
# 8                          Omakasa     False  40.722060 -73.996740    $$
# 9                      Aunt Jake's     False  40.719031 -73.997716    $$
# 10                  Silver Factory     False  40.709227 -73.958598    $$
# 11              Ipanema Restaurant     False  40.757072 -73.980780    $$
# 12    Carmine's Italian Restaurant     False  40.757490 -73.986620    $$
# 13                      Thai Villa     False  40.739020 -73.990650    $$
# 14  Tava Turkish and Mediterranean     False  40.673160 -73.983300    $$
# 15                   Tanner Smiths     False  40.764420 -73.981690    $$
# 16                 Juliana's Pizza     False  40.702615 -73.993416    $$
# 17                       La Sirene     False  40.724364 -74.005709   $$$
# 18                        Concrete     False  40.697700 -73.936800    $$
# 19                    Rabbit House     False  40.717250 -73.993290    $$
# 20                    Atrium Dumbo     False  40.703390 -73.990492    $$
# 21                   Junzi Kitchen     False  40.728780 -74.000610    $$
# 22             Trattoria Trecolori     False  40.759980 -73.986710    $$
# 23                    Cafe Mogador     False  40.719747 -73.959993    $$
# 24                             Bea     False  40.759197 -73.992336    $$
# 25                        The Boil     False  40.719740 -73.993390    $$
# 26                  Joe's Shanghai     False  40.714669 -73.997760    $$
# 27          Boucherie West Village     False  40.733063 -74.002877   $$$
# 28                          Bunker     False  40.710564 -73.923398    $$
# 29                          Balzem     False  40.721388 -73.995415    $$
# 30                        Bernie's     False  40.721890 -73.950570  None
# 31                         Up Thai     False  40.769828 -73.957633    $$
# 32                       TongKatsu     False  40.719290 -73.986470    $$
# 33                     Root & Bone     False  40.722720 -73.983340    $$
# 34                Thursday Kitchen     False  40.727500 -73.983800    $$
# 35           Fishmarket Restaurant     False  40.707170 -74.001920    $$
# 36               Pepe Rosso Social     False  40.720070 -73.996180    $$
# 37               Midwinter Kitchen     False  40.735420 -73.982930    $$
# 38                    Pig and Khao     False  40.719260 -73.984750    $$
# 39                            Soco     False  40.693866 -73.964535    $$
# 40                       Ippudo NY     False  40.730920 -73.990150    $$
# 41                     Cock & Bull     False  40.756091 -73.980486    $$
# 42                         Bijan's     False  40.688030 -73.986710    $$
# 43                            Raku     False  40.727280 -74.002520    $$
# 44                            Raku     False  40.726499 -73.986653    $$
# 45            Angeletto Restaurant     False  40.753188 -73.969365    $$
# 46                       Pio Pio 8     False  40.760506 -73.994564    $$
# 47                      Olio e Piú     False  40.733826 -73.999852    $$
# 48                        L'Artusi     False  40.733714 -74.005068   $$$
# 49                         Wok Wok     False  40.714060 -73.998830    $$
#
#     rating                                        categories         phone
# 0      4.5                               [French, Wine Bars]  +12125332962
# 1      4.0                     [Thai, Malaysian, Vietnamese]  +12122545370
# 2      4.0                                       [Taiwanese]  +16468820231
# 3      4.0              [American (Traditional), Gastropubs]  +17184513825
# 4      4.0                [Seafood, Burgers, American (New)]  +16468337532
# 5      3.5                    [Grocery, Italian, Meat Shops]  +12128972895
# 6      4.0  [Comfort Food, Southern, American (Traditional)]  +12124705566
# 7      4.5                    [Seafood, Wine Bars, Beer Bar]  +16467915400
# 8      4.0          [Asian Fusion, Japanese, American (New)]  +19174727954
# 9      4.0                 [Italian, Wine Bars, Pasta Shops]  +16468580470
# 10     4.5                                    [Korean, Bars]  +13477253017
# 11     4.0           [Brazilian, Latin American, Portuguese]  +12127305848
# 12     4.0         [Italian, Venues & Event Spaces, Seafood]  +12122213800
# 13     4.5                  [Thai, Asian Fusion, Vegetarian]  +12128029999
# 14     5.0                          [Turkish, Mediterranean]  +17184995600
# 15     4.0      [Cocktail Bars, American (New), Speakeasies]  +16465902034
# 16     4.5                                           [Pizza]  +17185966700
# 17     4.5                                          [French]  +12129253061
# 18     4.0              [Bars, Breakfast & Brunch, Sicilian]  +19179668440
# 19     4.5               [Tapas Bars, Asian Fusion, Izakaya]  +12123434200
# 20     4.0                          [American (New), French]  +17188581095
# 21     4.5                  [Chinese, Noodles, Asian Fusion]  +16468640277
# 22     4.0                                         [Italian]  +12129974540
# 23     4.5                                        [Moroccan]  +17184869222
# 24     4.0                   [American (New), Cocktail Bars]  +12126021910
# 25     4.5            [Cajun/Creole, Seafood, Live/Raw Food]  +12129258815
# 26     4.0    [Shanghainese, Seafood, Venues & Event Spaces]  +12122338888
# 27     4.5              [French, Cocktail Bars, Steakhouses]  +12128371616
# 28     4.0                                      [Vietnamese]  +17183864282
# 29     4.0    [Mediterranean, Tapas/Small Plates, Wine Bars]  +16468377033
# 30     4.5             [American (New), Beer Bar, Wine Bars]  +13475296400
# 31     4.5                              [Thai, Asian Fusion]  +12122561188
# 32     5.0            [Japanese, Asian Fusion, Comfort Food]  +12122543246
# 33     4.0                [Southern, Comfort Food, Desserts]  +16466827080
# 34     4.5      [Korean, American (New), Tapas/Small Plates]
# 35     4.5                  [Seafood, Chinese, Asian Fusion]  +19173638101
# 36     4.0                                         [Italian]  +12122190019
# 37     4.5                                  [American (New)]  +12125058500
# 38     4.0                    [Filipino, Thai, Asian Fusion]  +12129204485
# 39     4.0               [Cajun/Creole, Barbeque, Soul Food]  +17187831936
# 40     4.0                                           [Ramen]
# 41     4.0                       [British, Pubs, Gastropubs]  +12128191900
# 42     4.0                   [American (New), Cocktail Bars]  +17188555574
# 43     4.5                               [Japanese, Noodles]  +12129894797
# 44     4.5                               [Japanese, Noodles]  +12122281324
# 45     4.5                                         [Italian]  +12122351227
# 46     4.0                        [Latin American, Peruvian]  +12124592929
# 47     4.0              [Pizza, Italian, Breakfast & Brunch]  +12122436546
# 48     4.5                                         [Italian]  +12122555757
# 49     4.0                                 [Malaysian, Thai]  +19173883627
